# %%
from pyspark import SparkContext
from pyspark.sql import functions as f
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, IntegerType, NullType, ShortType, DateType, BooleanType, BinaryType
from pyspark.sql import SQLContext, SparkSession
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from pyspark.sql import types
import pyspark.sql.functions as F
SEED = 7

import warnings
warnings.filterwarnings('ignore')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
username = dbutils.notebook.entry_point.getDbutils().notebook().getContext().tags().apply('user')
private_path = 'dbfs:/user/' + username
project_path = "dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dataset = "test"
hours = 4      # hours before flight to put into join and pivot - WARNING: changing this mean you must also change the hard-coded query for pivot below
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Load weather and flight data

# %%
weather_ready = f"weather_all.parquet"
flights_ready = f"{dataset}_flights.parquet"
weather = spark.read.option("header", "true").parquet(f"{project_path}/{weather_ready}/*.parquet")
weather.printSchema()
weather.createOrReplaceTempView("weather2")

flights = spark.read.option("header", "true").parquet(f"{project_path}/{flights_ready}/*.parquet")
flights.printSchema()
flights.createOrReplaceTempView("flights2")

print("weather:",weather.count() ,"rows")
print("flights:",flights.count(), "rows")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- airport: string (nullable = true)
# -- date: timestamp (nullable = true)
# -- wind_angle: string (nullable = true)
# -- wind_speed: double (nullable = true)
# -- ceiling: string (nullable = true)
# -- visibility: string (nullable = true)
# -- temperature: double (nullable = true)
# -- dewpoint: double (nullable = true)
# -- pressure: double (nullable = true)
#
# root
# -- origin: string (nullable = true)
# -- destination: string (nullable = true)
# -- year: integer (nullable = true)
# -- month: integer (nullable = true)
# -- day_of_month: integer (nullable = true)
# -- day_of_week: integer (nullable = true)
# -- crs_dep_time_utc: timestamp (nullable = true)
# -- naive_crs_arr_time_utc: timestamp (nullable = true)
# -- tail_num: string (nullable = true)
# -- op_carrier: string (nullable = true)
# -- distance: double (nullable = true)
# -- dep_blk: integer (nullable = true)
# -- dep_del15: double (nullable = true)
# -- nas_delay: double (nullable = true)
# -- carrier_delay: double (nullable = true)
# -- weather_delay: double (nullable = true)
# -- security_delay: double (nullable = true)
# -- late_aircraft_delay: double (nullable = true)
# -- arr_delay: double (nullable = true)
# -- crs_arr_time_utc: timestamp (nullable = true)
# -- arr_hour_utc: timestamp (nullable = true)
# -- dep_hour_utc: timestamp (nullable = true)
# -- hour: timestamp (nullable = true)
# -- del_tail_num: string (nullable = true)
# -- equipment_delayed: boolean (nullable = true)
# -- dest_pagerank: double (nullable = true)
# -- src_pagerank: double (nullable = true)
# -- weight: double (nullable = true)
# -- avg_trips_per_day: double (nullable = true)
# -- avg_tp_per_day: long (nullable = true)
# -- avg_flights_per_day: double (nullable = true)
# -- avg_car_per_day: long (nullable = true)
# -- avg_car_flights_per_day: double (nullable = true)
#
# weather: 178390796 rows
# flights: 6853063 rows
# </div>

# %% [markdown]
# ## Augment with time block data

# %%
weather = spark.sql("""
  select 
    weather2.*,
    date_trunc('HOUR', date) + interval 3 hour as hour2,
    date_trunc('HOUR', date) + interval 4 hour as hour3,
    date_trunc('HOUR', date) + interval 5 hour as hour4,
    date_trunc('HOUR', date) + interval 6 hour as hour5
  from 
    weather2
""").cache()
weather.createOrReplaceTempView("weather3")
weather.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- airport: string (nullable = true)
# -- date: timestamp (nullable = true)
# -- wind_angle: string (nullable = true)
# -- wind_speed: double (nullable = true)
# -- ceiling: string (nullable = true)
# -- visibility: string (nullable = true)
# -- temperature: double (nullable = true)
# -- dewpoint: double (nullable = true)
# -- pressure: double (nullable = true)
# -- hour2: timestamp (nullable = true)
# -- hour3: timestamp (nullable = true)
# -- hour4: timestamp (nullable = true)
# -- hour5: timestamp (nullable = true)
#
# </div>

# %% [markdown]
# ## Join flights and weather

# %%
joins = []
for i in range(2, 2+hours):
  join_str = "(weather3.hour"+str(i)+" == flights2.dep_hour_utc)" 
  data = spark.sql(f"""
    select
        flights2.*,
        weather3.*,
        (weather3.airport == flights2.origin) as weather_is_origin,
        {str(i)} as hour_diff
    from 
        weather3,
        flights2
    where
        (weather3.airport == flights2.origin or weather3.airport == flights2.destination)
        and ({join_str})
    """) \
    .drop("airport","date", "hour2", "hour3", "hour4", "hour5") \
    .cache()
  data.createOrReplaceTempView("join"+str(i))
  #data.count()
  joins.append(data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
len(joins)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 4</div>

# %%
joins[0].printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- origin: string (nullable = true)
# -- destination: string (nullable = true)
# -- year: integer (nullable = true)
# -- month: integer (nullable = true)
# -- day_of_month: integer (nullable = true)
# -- day_of_week: integer (nullable = true)
# -- crs_dep_time_utc: timestamp (nullable = true)
# -- naive_crs_arr_time_utc: timestamp (nullable = true)
# -- tail_num: string (nullable = true)
# -- op_carrier: string (nullable = true)
# -- distance: double (nullable = true)
# -- dep_blk: integer (nullable = true)
# -- dep_del15: double (nullable = true)
# -- nas_delay: double (nullable = true)
# -- carrier_delay: double (nullable = true)
# -- weather_delay: double (nullable = true)
# -- security_delay: double (nullable = true)
# -- late_aircraft_delay: double (nullable = true)
# -- arr_delay: double (nullable = true)
# -- crs_arr_time_utc: timestamp (nullable = true)
# -- arr_hour_utc: timestamp (nullable = true)
# -- dep_hour_utc: timestamp (nullable = true)
# -- hour: timestamp (nullable = true)
# -- del_tail_num: string (nullable = true)
# -- equipment_delayed: boolean (nullable = true)
# -- dest_pagerank: double (nullable = true)
# -- src_pagerank: double (nullable = true)
# -- weight: double (nullable = true)
# -- avg_trips_per_day: double (nullable = true)
# -- avg_tp_per_day: long (nullable = true)
# -- avg_flights_per_day: double (nullable = true)
# -- avg_car_per_day: long (nullable = true)
# -- avg_car_flights_per_day: double (nullable = true)
# -- wind_angle: string (nullable = true)
# -- wind_speed: double (nullable = true)
# -- ceiling: string (nullable = true)
# -- visibility: string (nullable = true)
# -- temperature: double (nullable = true)
# -- dewpoint: double (nullable = true)
# -- pressure: double (nullable = true)
# -- weather_is_origin: boolean (nullable = true)
# -- hour_diff: integer (nullable = false)
#
# </div>

# %%
data = joins[0]
for i in range(1,len(joins)):
    print(i)
    data = data.union(joins[i])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1
# 2
# 3
# </div>

# %%
data.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- origin: string (nullable = true)
# -- destination: string (nullable = true)
# -- year: integer (nullable = true)
# -- month: integer (nullable = true)
# -- day_of_month: integer (nullable = true)
# -- day_of_week: integer (nullable = true)
# -- crs_dep_time_utc: timestamp (nullable = true)
# -- naive_crs_arr_time_utc: timestamp (nullable = true)
# -- tail_num: string (nullable = true)
# -- op_carrier: string (nullable = true)
# -- distance: double (nullable = true)
# -- dep_blk: integer (nullable = true)
# -- dep_del15: double (nullable = true)
# -- nas_delay: double (nullable = true)
# -- carrier_delay: double (nullable = true)
# -- weather_delay: double (nullable = true)
# -- security_delay: double (nullable = true)
# -- late_aircraft_delay: double (nullable = true)
# -- arr_delay: double (nullable = true)
# -- crs_arr_time_utc: timestamp (nullable = true)
# -- arr_hour_utc: timestamp (nullable = true)
# -- dep_hour_utc: timestamp (nullable = true)
# -- hour: timestamp (nullable = true)
# -- del_tail_num: string (nullable = true)
# -- equipment_delayed: boolean (nullable = true)
# -- dest_pagerank: double (nullable = true)
# -- src_pagerank: double (nullable = true)
# -- weight: double (nullable = true)
# -- avg_trips_per_day: double (nullable = true)
# -- avg_tp_per_day: long (nullable = true)
# -- avg_flights_per_day: double (nullable = true)
# -- avg_car_per_day: long (nullable = true)
# -- avg_car_flights_per_day: double (nullable = true)
# -- wind_angle: string (nullable = true)
# -- wind_speed: double (nullable = true)
# -- ceiling: string (nullable = true)
# -- visibility: string (nullable = true)
# -- temperature: double (nullable = true)
# -- dewpoint: double (nullable = true)
# -- pressure: double (nullable = true)
# -- weather_is_origin: boolean (nullable = true)
# -- hour_diff: integer (nullable = false)
#
# </div>

# %%
save = True
if save:
    data.write.mode("overwrite").format("parquet").save(f"{project_path}/{dataset}_join.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data = spark.read.option("header", "true").parquet(f"{project_path}/{dataset}_join.parquet/*.parquet")
data.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: 66951418</div>

# %%
weather = spark.read.option("header", "true").parquet(f"{project_path}/{weather_ready}/*.parquet")
weather.printSchema()
weather.createOrReplaceTempView("weather2")
display(spark.sql("select * from weather2 limit 10"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- airport: string (nullable = true)
# -- date: timestamp (nullable = true)
# -- wind_angle: string (nullable = true)
# -- wind_speed: double (nullable = true)
# -- ceiling: string (nullable = true)
# -- visibility: string (nullable = true)
# -- temperature: double (nullable = true)
# -- dewpoint: double (nullable = true)
# -- pressure: double (nullable = true)
#
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>airport</th><th>date</th><th>wind_angle</th><th>wind_speed</th><th>ceiling</th><th>visibility</th><th>temperature</th><th>dewpoint</th><th>pressure</th></tr></thead><tbody><tr><td>DTA</td><td>2017-01-01T06:55:00.000+0000</td><td>180</td><td>2.6</td><td>00030</td><td>000000</td><td>null</td><td>null</td><td>9999.9</td></tr><tr><td>DTA</td><td>2017-01-01T07:15:00.000+0000</td><td>170</td><td>2.1</td><td>00030</td><td>000000</td><td>-15.0</td><td>-16.0</td><td>9999.9</td></tr><tr><td>DTA</td><td>2017-01-01T07:35:00.000+0000</td><td>999</td><td>0.0</td><td>00030</td><td>000000</td><td>-15.0</td><td>-16.0</td><td>9999.9</td></tr><tr><td>DTA</td><td>2017-01-01T07:55:00.000+0000</td><td>999</td><td>0.0</td><td>00030</td><td>000000</td><td>null</td><td>null</td><td>9999.9</td></tr><tr><td>DTA</td><td>2017-01-01T08:15:00.000+0000</td><td>999</td><td>0.0</td><td>00030</td><td>000000</td><td>-15.0</td><td>-17.0</td><td>9999.9</td></tr><tr><td>DTA</td><td>2017-01-01T08:35:00.000+0000</td><td>120</td><td>2.1</td><td>00030</td><td>000000</td><td>-15.0</td><td>-16.0</td><td>9999.9</td></tr><tr><td>DTA</td><td>2017-01-01T08:55:00.000+0000</td><td>070</td><td>2.1</td><td>00030</td><td>000000</td><td>null</td><td>null</td><td>9999.9</td></tr><tr><td>DTA</td><td>2017-01-01T09:15:00.000+0000</td><td>070</td><td>2.1</td><td>00030</td><td>000402</td><td>-14.0</td><td>-15.0</td><td>9999.9</td></tr><tr><td>DTA</td><td>2017-01-01T09:35:00.000+0000</td><td>999</td><td>0.0</td><td>00030</td><td>000402</td><td>-14.0</td><td>-15.0</td><td>9999.9</td></tr><tr><td>DTA</td><td>2017-01-01T09:55:00.000+0000</td><td>070</td><td>2.1</td><td>00030</td><td>000000</td><td>null</td><td>null</td><td>9999.9</td></tr></tbody></table></div>

# %%
data.createOrReplaceTempView("join")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# display(spark.sql("""
#   select 
#     * 
#   from 
#     join 
#   where 
#     origin=='ATL' 
#     and crs_dep_time_utc < '2015-01-02'
#   limit
#     10
# """))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
tlist = ["("+str(i)+",true) origin_"+str(i) for i in range(2,2+hours)]
flist = ["("+str(i)+",false) destination_"+str(i) for i in range(2,2+hours)]
pivot_str = ",\n".join(tlist+flist)
print(pivot_str)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(2,true) origin_2,
# (3,true) origin_3,
# (4,true) origin_4,
# (5,true) origin_5,
# (2,false) destination_2,
# (3,false) destination_3,
# (4,false) destination_4,
# (5,false) destination_5
# </div>

# %%
pivot = spark.sql(f"""
    select 
        *
    from
        join
    pivot (
        avg(wind_angle) as wind_angle,
        max(wind_speed) as wind_speed,     
        min(ceiling) as ceiling,
        min(visibility) as visibility, 
        min(temperature) as temperature,
        min(dewpoint) as dewpoint,
        min(pressure) as pressure
        for (hour_diff,weather_is_origin) in (
            {pivot_str}
        )
    )
""").cache()
# pivot.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
if save:
  pivot.write.mode("overwrite").format("parquet").save(f"{project_path}/{dataset}.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
if save and dataset == "train":
    pivot \
      .filter("crs_dep_time_utc < '2015-04-01'") \
      .write.mode("overwrite").format("parquet").save(f"{project_path}/train_3m.parquet")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pivot = spark.read.option("header", "true").parquet(f"{project_path}/{dataset}.parquet/*.parquet")
pivot.createOrReplaceTempView("pivot")
pivot.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: 6841352</div>

# %%
if dataset == "train":
  display(spark.sql("""
  select 
    * 
  from 
    pivot 
  where 
    origin=='OGG' 
    and crs_dep_time_utc > '2015-02-01'
    and crs_dep_time_utc < '2015-02-02'
  limit
    10
"""))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dbutils.fs.ls(project_path))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/Chitra_feature_data/</td><td>Chitra_feature_data/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airline_singleday.parquet/</td><td>airline_singleday.parquet/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airlines_3m_features_ext.parquet/</td><td>airlines_3m_features_ext.parquet/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airlines_3m_full_features.parquet/</td><td>airlines_3m_full_features.parquet/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airlines_weather_data/</td><td>airlines_weather_data/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airport-timezones.csv</td><td>airport-timezones.csv</td><td>439779</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airport_edges/</td><td>airport_edges/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airport_edges_1_year/</td><td>airport_edges_1_year/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airport_edges_3_month/</td><td>airport_edges_3_month/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airport_edges_4_year/</td><td>airport_edges_4_year/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airport_thruput/</td><td>airport_thruput/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airport_vertices/</td><td>airport_vertices/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airport_vertices_1_year/</td><td>airport_vertices_1_year/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airport_vertices_3_month/</td><td>airport_vertices_3_month/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/airport_vertices_4_year/</td><td>airport_vertices_4_year/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/aw_data_1day/</td><td>aw_data_1day/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/chitra_weather_relevant/</td><td>chitra_weather_relevant/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/destination_weather_avgs/</td><td>destination_weather_avgs/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/dev.parquet/</td><td>dev.parquet/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/dev_flights.parquet/</td><td>dev_flights.parquet/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/dev_join.parquet/</td><td>dev_join.parquet/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/flight_full_features.parquet/</td><td>flight_full_features.parquet/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/flights_features_3_month.parquet/</td><td>flights_features_3_month.parquet/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/flights_ready_1_year.parquet/</td><td>flights_ready_1_year.parquet/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/flights_ready_3_month.parquet/</td><td>flights_ready_3_month.parquet/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/flights_ready_4_year.parquet/</td><td>flights_ready_4_year.parquet/</td><td>0</td></tr><tr><td>dbfs:/user/chitra.agastya@ischool.berkeley.edu/FinalProject/flights_ready_full.parquet/</ ...

# %%
print("done with", dataset)
pivot.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">done with test
# root
# -- origin: string (nullable = true)
# -- destination: string (nullable = true)
# -- year: integer (nullable = true)
# -- month: integer (nullable = true)
# -- day_of_month: integer (nullable = true)
# -- day_of_week: integer (nullable = true)
# -- crs_dep_time_utc: timestamp (nullable = true)
# -- naive_crs_arr_time_utc: timestamp (nullable = true)
# -- tail_num: string (nullable = true)
# -- op_carrier: string (nullable = true)
# -- distance: double (nullable = true)
# -- dep_blk: integer (nullable = true)
# -- dep_del15: double (nullable = true)
# -- nas_delay: double (nullable = true)
# -- carrier_delay: double (nullable = true)
# -- weather_delay: double (nullable = true)
# -- security_delay: double (nullable = true)
# -- late_aircraft_delay: double (nullable = true)
# -- arr_delay: double (nullable = true)
# -- crs_arr_time_utc: timestamp (nullable = true)
# -- arr_hour_utc: timestamp (nullable = true)
# -- dep_hour_utc: timestamp (nullable = true)
# -- hour: timestamp (nullable = true)
# -- del_tail_num: string (nullable = true)
# -- equipment_delayed: boolean (nullable = true)
# -- dest_pagerank: double (nullable = true)
# -- src_pagerank: double (nullable = true)
# -- weight: double (nullable = true)
# -- avg_trips_per_day: double (nullable = true)
# -- avg_tp_per_day: long (nullable = true)
# -- avg_flights_per_day: double (nullable = true)
# -- avg_car_per_day: long (nullable = true)
# -- avg_car_flights_per_day: double (nullable = true)
# -- origin_2_wind_angle: double (nullable = true)
# -- origin_2_wind_speed: double (nullable = true)
# -- origin_2_ceiling: string (nullable = true)
# -- origin_2_visibility: string (nullable = true)
# -- origin_2_temperature: double (nullable = true)
# -- origin_2_dewpoint: double (nullable = true)
# -- origin_2_pressure: double (nullable = true)
# -- origin_3_wind_angle: double (nullable = true)
# -- origin_3_wind_speed: double (nullable = true)
# -- origin_3_ceiling: string (nullable = true)
# -- origin_3_visibility: string (nullable = true)
# -- origin_3_temperature: double (nullable = true)
# -- origin_3_dewpoint: double (nullable = true)
# -- origin_3_pressure: double (nullable = true)
# -- origin_4_wind_angle: double (nullable = true)
# -- origin_4_wind_speed: double (nullable = true)
# -- origin_4_ceiling: string (nullable = true)
# -- origin_4_visibility: string (nullable = true)
# -- origin_4_temperature: double (nullable = true)
# -- origin_4_dewpoint: double (nullable = true)
# -- origin_4_pressure: double (nullable = true)
# -- origin_5_wind_angle: double (nullable = true)
# -- origin_5_wind_speed: double (nullable = true)
# -- origin_5_ceiling: string (nullable = true)
# -- origin_5_visibility: string (nullable = true)
# -- origin_5_temperature: double (nullable = true)
# -- origin_5_dewpoint: double (nullable = true)
# -- origin_5_pressure: double (nullable = true)
# -- destination_2_wind_angle: double (nullable = true)
# -- destination_2_wind_speed: double (nullable = true)
# -- destination_2_ceiling: string (nullable = true)
# -- destination_2_visibility: string (nullable = true)
# -- destination_2_temperature: double (nullable = true)
# -- destination_2_dewpoint: double (nullable = true)
# -- destination_2_pressure: double (nullable = true)
# -- destination_3_wind_angle: double (nullable = true)
# -- destination_3_wind_speed: double (nullable = true)
# -- destination_3_ceiling: string (nullable = true)
# -- destination_3_visibility: string (nullable = true)
# -- destination_3_temperature: double (nullable = true)
# -- destination_3_dewpoint: double (nullable = true)
# -- destination_3_pressure: double (nullable = true)
# -- destination_4_wind_angle: double (nullable = true)
# -- destination_4_wind_speed: double (nullable = true)
# -- destination_4_ceiling: string (nullable = true)
# -- destination_4_visibility: string (nullable = true)
# -- destination_4_temperature: double (nullable = true)
# -- destination_4_dewpoint: double (nullable = true)
# -- destination_4_pressure: double (nullable = true)
# -- destination_5_wind_angle: double (nullable = true)
# -- destination_5_wind_speed: double (nullable = true)
# -- destination_5_ceiling: string (nullable = true)
# -- destination_5_visibility: string (nullable = true)
# -- destination_5_temperature: double (nullable = true)
# -- destination_5_dewpoint: double (nullable = true)
# -- destination_5_pressure: double (nullable = true)
#
# </div>
